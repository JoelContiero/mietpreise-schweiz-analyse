# %% [markdown]
# # 02 – Analyse
#
# Leitfrage: Wie stark sind die Wohnungsmieten in der Schweiz in den letzten 10–15 Jahren gestiegen — und hielt das mit der Lohn- und Teuerungsentwicklung Schritt?
#
# Pro Auswertung ein Diagramm + ein kurzes Fazit in eigenen Worten.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
PROCESSED = "../data/processed"

# %%
# miete = pd.read_csv(f"{PROCESSED}/mietpreisindex_clean.csv")
# miete.head()

# %% [markdown]
# ## Auswertung 1: Mietentwicklung über die Zeit
#
# _Fazit:_

# %% [markdown]
# ## Auswertung 2: Miete vs. Teuerung (LIK) vs. Löhne
#
# _Fazit:_

# %% [markdown]
# ## Key Findings
#
# - ...
# - ...
# - ...
